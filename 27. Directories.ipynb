# %%
import os
def check_file_type():
    path = input("Please enter the path of the files: ")
    for filename in os.listdir(path):
        fullname = os.path.join(path, filename)
        if os.path.isdir(fullname):
            #print("{} is a directory".format(fullname))
            continue
        else:
            print("{} is a file".format(fullname))

check_file_type()
# Out:
# Please enter the path of the files: C:\Users\Dell\
# C:\Users\Dell\.appletviewer is a file
# C:\Users\Dell\.bash_history is a file
# C:\Users\Dell\.condarc is a file
# C:\Users\Dell\.gitconfig is a file
# C:\Users\Dell\.labelImgSettings.pkl is a file
# C:\Users\Dell\.minttyrc is a file
# C:\Users\Dell\.perlcriticrc is a file
# C:\Users\Dell\.swp is a file
# C:\Users\Dell\abc.py is a file
# C:\Users\Dell\Abnormality_Detection.ipynb is a file
# C:\Users\Dell\Advertising Budget and Sales.csv is a file
# C:\Users\Dell\Advertising.csv is a file
# C:\Users\Dell\Agmarknet_Price_Report.xlsx is a file
# C:\Users\Dell\Agrilink_Data_Science_Assignment.ipynb is a file
# C:\Users\Dell\area.py is a file
# C:\Users\Dell\Areas.py is a file
# C:\Users\Dell\Assignment IBM_Employee_Attrition_Prediction.ipynb is a file
# C:\Users\Dell\Assignment_ML_data_manipulation.ipynb is a file
# C:\Users\Dell\Assisted_Titanic-checkpoint.ipynb is a file
# C:\Users\Dell\Assisted_Titanic-Copy2-checkpoint.ipynb is a file
# C:\Users\Dell\Assisted_titanic_1-checkpoint.ipynb is a file
# C:\Users\Dell\auto_data.csv is a file
# C:\Users\Dell\banglore_home_price_model.pickle is a file
# C:\Users\Dell\Bar Plot.png is a file
# C:\Users\Dell\Bar_plot.pdf is a file
# C:\Users\Dell\Bar_plot.png is a file
# C:\Users\Dell\Bengaluru_House_Data.csv is a file
# C:\Users\Dell\Big Mart Sales - predict the product sales with regression-checkpoint.ipynb is a file
# C:\Users\Dell\Big Mart Sales - predict the product sales with regression-Copy2-checkpoint.ipynb is a file
# C:\Users\Dell\Big Mart Sales-checkpoint.ipynb is a file
# C:\Users\Dell\bigmart_test.csv is a file
# C:\Users\Dell\bigmart_train.csv is a file
# C:\Users\Dell\body_mass vs island.png is a file
# C:\Users\Dell\boxplot.png is a file
# C:\Users\Dell\car.csv is a file
# C:\Users\Dell\columns.json is a file
# C:\Users\Dell\Countries with GDP.txt is a file
# C:\Users\Dell\Cyclone_cone_draft.csv is a file
# C:\Users\Dell\Cyclone_Gas_Outlet_Temp.csv is a file
# C:\Users\Dell\Cyclone_Inlet_Draft.csv is a file
# C:\Users\Dell\Cyclone_Inlet_Gas_Temp.csv is a file
# C:\Users\Dell\Cyclone_Material_Temp.csv is a file
# C:\Users\Dell\Cyclone_Outlet_Gas_draft.csv is a file
# C:\Users\Dell\Data+analysis+with+Python+-+NumPy (2).ipynb is a file
# C:\Users\Dell\DataAnalysisProjects-master.zip is a file
# C:\Users\Dell\data_replace_function_using_pandas.ipynb is a file
# C:\Users\Dell\Data_visualization.ipynb is a file
# C:\Users\Dell\Data_visualization_ch3.ipynb is a file
# C:\Users\Dell\Data_visualization_ch4.ipynb is a file
# C:\Users\Dell\db_dump.sql is a file
# C:\Users\Dell\different_ways_to_create_dataframe.ipynb is a file
# C:\Users\Dell\EDA using Python - Pandas and Matplotlib (1).ipynb is a file
# C:\Users\Dell\Exact_Space_Assignment_Abnormality_Detection.ipynb is a file
# C:\Users\Dell\Exploratory_data_Analysis.ipynb is a file
# C:\Users\Dell\faa_ai_prelim.csv is a file
# C:\Users\Dell\FDNY.csv is a file
# C:\Users\Dell\final_dataframe.csv is a file
# C:\Users\Dell\final_dataframe.xlsx is a file
# C:\Users\Dell\Fittlyf_internship.ipynb is a file
# C:\Users\Dell\Fraudulent_Transaction_Prediction_Model.ipynb is a file
# C:\Users\Dell\from_kaggle_notebook.ipynb is a file
# C:\Users\Dell\GroupByFeature_pandas.ipynb is a file
# C:\Users\Dell\handle_missing_data.ipynb is a file
# C:\Users\Dell\health_checks.py is a file
# C:\Users\Dell\Heatmap.jpg is a file
# C:\Users\Dell\Heatmap.png is a file
# C:\Users\Dell\hello_world.py is a file
# C:\Users\Dell\hello_world.pyy is a file
# C:\Users\Dell\Histograms.ipynb is a file
# C:\Users\Dell\IBM Attrition Data.csv is a file
# C:\Users\Dell\image.jpeg is a file
# C:\Users\Dell\imdb_labelled.txt is a file
# C:\Users\Dell\INSAID-fraudulent_transactions_prediction.ipynb is a file
# C:\Users\Dell\Intern_data.csv is a file
# C:\Users\Dell\joke.txt is a file
# C:\Users\Dell\log_normal_distribution.ipynb is a file
# C:\Users\Dell\Machine Learning Project(Real Estate Price Prediction).ipynb is a file
# C:\Users\Dell\Math & Statistics Khan Academy(Rough Work).ipynb is a file
# C:\Users\Dell\middle_tn_schools.csv is a file
# C:\Users\Dell\Mohammad_Mohsin_DataScience.zip is a file
# C:\Users\Dell\mtcars.csv is a file
# C:\Users\Dell\mydocs.py is a file
# C:\Users\Dell\NLP_Pipeline_and_grid_search.ipynb is a file
# C:\Users\Dell\NLP_practice.ipynb is a file
# C:\Users\Dell\north_america_2000_2010.csv is a file
# C:\Users\Dell\novel.txt is a file
# C:\Users\Dell\NTUSER.DAT is a file
# C:\Users\Dell\ntuser.dat.LOG1 is a file
# C:\Users\Dell\ntuser.dat.LOG2 is a file
# C:\Users\Dell\NTUSER.DAT{4b8d9623-f7bc-11e9-b484-d6be356bbefc}.TxR.0.regtrans-ms is a file
# C:\Users\Dell\NTUSER.DAT{4b8d9623-f7bc-11e9-b484-d6be356bbefc}.TxR.blf is a file
# C:\Users\Dell\NTUSER.DAT{4b8d9624-f7bc-11e9-b484-d6be356bbefc}.TM.blf is a file
# C:\Users\Dell\NTUSER.DAT{4b8d9624-f7bc-11e9-b484-d6be356bbefc}.TMContainer00000000000000000001.regtrans-ms is a file
# C:\Users\Dell\NTUSER.DAT{4b8d9624-f7bc-11e9-b484-d6be356bbefc}.TMContainer00000000000000000002.regtrans-ms is a file
# C:\Users\Dell\ntuser.ini is a file
# C:\Users\Dell\numpy_array.ipynb is a file
# C:\Users\Dell\numpy_diter_exercise.ipynb is a file
# C:\Users\Dell\numpy_practice_set.ipynb is a file
# C:\Users\Dell\Ohio_state_data.txt is a file
# C:\Users\Dell\otp_generator.py is a file
# C:\Users\Dell\outlier_removal.ipynb is a file
# C:\Users\Dell\Output.csv is a file
# C:\Users\Dell\pairplot.png is a file
# C:\Users\Dell\pandas_concatenate.ipynb is a file
# C:\Users\Dell\pandas_dataframe_basics.ipynb is a file
# C:\Users\Dell\pandas_dataframe_basics1.ipynb is a file
# C:\Users\Dell\pandas_dataframe_basics2.ipynb is a file
# C:\Users\Dell\pandas_merge_function.ipynb is a file
# C:\Users\Dell\pandas_simplilearn.ipynb is a file
# C:\Users\Dell\Pandas_SQL_Operation.ipynb is a file
# C:\Users\Dell\Peepoye_Network_Data_Analysis_Assignment.ipynb is a file
# C:\Users\Dell\Penguins.csv is a file
# C:\Users\Dell\Pie Chart.ipynb is a file
# C:\Users\Dell\Pie_Chart.png is a file
# C:\Users\Dell\pima-indians-diabetes.data is a file
# C:\Users\Dell\pima-indians-diabetes.names is a file
# C:\Users\Dell\planets.csv is a file
# C:\Users\Dell\plotting.png is a file
# C:\Users\Dell\plotting_exercise.ipynb is a file
# C:\Users\Dell\Plotting_exercise2.ipynb is a file
# C:\Users\Dell\practice_simplilearn.ipynb is a file
# C:\Users\Dell\programming.py is a file
# C:\Users\Dell\project.csv is a file
# C:\Users\Dell\Python_Tutorial_By_CodeBasics - 01.ipynb is a file
# C:\Users\Dell\read_write_excel_csv_files.ipynb is a file
# C:\Users\Dell\region.csv is a file
# C:\Users\Dell\regresfilename.pkl is a file
# C:\Users\Dell\Salaries.csv is a file
# C:\Users\Dell\SalaryGender.csv is a file
# C:\Users\Dell\Saving_chart_to_our_file.ipynb is a file
# C:\Users\Dell\Scipy_practice.ipynb is a file
# C:\Users\Dell\Seaborn_ex1.ipynb is a file
# C:\Users\Dell\Seaborn_ex2.ipynb is a file
# C:\Users\Dell\seaborn_ex3.ipynb is a file
# C:\Users\Dell\seaborn_ex4.ipynb is a file
# C:\Users\Dell\seaborn_ex5.ipynb is a file
# C:\Users\Dell\Seaborn_ex6.ipynb is a file
# C:\Users\Dell\Seaborn_ex7.ipynb is a file
# C:\Users\Dell\Seaborn_ex8.ipynb is a file
# C:\Users\Dell\Society_Mutter_google pegasus-xsum assignment(Text Summarizer).ipynb is a file
# C:\Users\Dell\south_america_2000_2010.csv is a file
# C:\Users\Dell\SpamCollection is a file
# C:\Users\Dell\SQL with python.ipynb is a file
# C:\Users\Dell\stocks_data.csv is a file
# C:\Users\Dell\stocks_data.xlsx is a file
# C:\Users\Dell\Stocks_Weather.xlsx is a file
# C:\Users\Dell\test.csv is a file
# C:\Users\Dell\train.csv is a file
# C:\Users\Dell\trained_model is a file
# C:\Users\Dell\Untitled.ipynb is a file
# C:\Users\Dell\user_input.py is a file
# C:\Users\Dell\Web Scrapping Assignment.ipynb is a file
# C:\Users\Dell\Web_Scrapping_using_SELENIUM.ipynb is a file
# C:\Users\Dell\wind_energy.csv is a file
# C:\Users\Dell\wind_energy.ipynb is a file
